# %%
#from arcgis.gis import GIS

# %%
import pandas as pd

# %%
import geopandas    #AŞKIIIIIMMMMM   as gpd yaparsan gpd.read demelisin!

# %%
import matplotlib
#import matplotlib.pyplot as plt

# %%
iller=geopandas.read_file("zip://gadm36_TUR_1.zip")

# %%
iller.head(10) #giste öznitelik tablosu
# Out:
#   GID_0  NAME_0     GID_1    NAME_1        VARNAME_1 NL_NAME_1 TYPE_1  \
# 0   TUR  Turkey   TUR.1_1     Adana           Seyhan      None     Il
# 1   TUR  Turkey   TUR.2_1  Adiyaman         Adıyaman      None     Il
# 2   TUR  Turkey   TUR.3_1     Afyon   Afyonkarahisar      None     Il
# 3   TUR  Turkey   TUR.4_1      Agri    Ağri|Karaköse      None     Il
# 4   TUR  Turkey   TUR.5_1   Aksaray             None      None     Il
# 5   TUR  Turkey   TUR.6_1    Amasya             None      None     Il
# 6   TUR  Turkey   TUR.7_1    Ankara    Ancara|Angora      None     Il
# 7   TUR  Turkey   TUR.8_1   Antalya  Adalia|Anatolia      None     Il
# 8   TUR  Turkey   TUR.9_1   Ardahan             None      None     Il
# 9   TUR  Turkey  TUR.10_1    Artvin            Çoruh      None     Il
#
#   ENGTYPE_1  CC_1 HASC_1                                           geometry
# 0  Province  None  TR.AA  MULTIPOLYGON (((35.20958 36.67875, 35.20958 36...
# ...

# %%
iller.geometry  #gisteki öznitelik tablosu
# Out:
# 0     MULTIPOLYGON (((35.20958 36.67875, 35.20958 36...
# 1     POLYGON ((38.68339 37.60323, 38.66182 37.59428...
# 2     POLYGON ((30.18261 37.90116, 30.18878 37.89117...
# 3     POLYGON ((43.71635 39.37020, 43.70746 39.36575...
# 4     POLYGON ((34.39513 38.19467, 34.39626 38.18270...
#                             ...
# 76    POLYGON ((29.57592 38.19177, 29.56290 38.19193...
# 77    POLYGON ((44.49154 38.30873, 44.49103 38.30837...
# 78    POLYGON ((29.03236 40.47859, 29.03236 40.47847...
# 79    POLYGON ((35.96196 39.91003, 35.96333 39.90491...
# 80    POLYGON ((31.49785 41.05423, 31.46466 41.05458...
# Name: geometry, Length: 81, dtype: geometry

# %%
iller.geometry[2]

# %%
iller.NAME_1[2] #index 2nin adı ne
# Out:
# 'Afyon'

# %%
#iller.plot()

# %%
type(iller)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
type(iller.geometry)
# Out:
# geopandas.geoseries.GeoSeries

# %%
#geometrideki poligonları saklayalım  illeri derece olarak hesapla
iller.geometry.area
# Out:
# <ipython-input-15-c25496d085e6>:2: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   iller.geometry.area
# 0     1.612729
# 1     0.759168
# 2     1.525553
# 3     1.079759
# 4     0.786662
#         ...
# 76    0.508203
# 77    2.179277
# 78    0.069144
# 79    1.380989
# 80    0.328679
# Length: 81, dtype: float64

# %%
#şehir merkezi/ geopanda geometric functions
iller.geometry.centroid
# Out:
# <ipython-input-16-0b9fc9168ad4>:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   iller.geometry.centroid
# 0     POINT (35.59445 37.46170)
# 1     POINT (38.33526 37.80429)
# 2     POINT (30.65645 38.62266)
# 3     POINT (43.26693 39.57460)
# 4     POINT (33.84149 38.37142)
#                 ...
# 76    POINT (29.36163 38.53510)
# 77    POINT (43.63811 38.47572)
# 78    POINT (29.11771 40.58542)
# 79    POINT (35.25198 39.66226)
# 80    POINT (31.84013 41.25204)
# Length: 81, dtype: geometry

# %%
merkezler=iller.geometry.centroid   #değişkene ata iller geodataframe
# Out:
# <ipython-input-17-8c09975c936d>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#
# ...

# %%
print(tren.geometry[1]) #line string geometri
# Out:
# LINESTRING (30.73027527777777 69.44805444444444, 30.72472555555555 69.4502786111111, 30.70444333333333 69.45055555555555, 30.68639083333333 69.44833361111111, 30.67055527777778 69.44527833333332, 30.65028027777778 69.44388944444444, 30.64657111111111 69.44411805555555, 30.62873611111111 69.44240388888888, 30.61545444444445 69.44099722222222, 30.59879166666667 69.44176944444445, 30.58702444444444 69.44314999999999, 30.56922722222222 69.44343611111111, 30.55567694444444 69.44208722222221, 30.53658333333333 69.43788277777777, 30.52578722222222 69.4357361111111, 30.50347055555556 69.43408444444444, 30.50000027777778 69.43423305555555, 30.48041777777777 69.43507194444443, 30.45336166666666 69.4368086111111, 30.43055333333333 69.43690916666667, 30.40560972222222 69.43559999999999, 30.37440222222222 69.43406944444445, 30.35823722222222 69.43305972222223, 30.3383125 69.43191805555554, 30.31250027777777 69.42923194444444, 30.28719833333333 69.42478166666666, 30.2650325 69.42266333333333, 30.2
# ...

# %%
#coğrafi veriyi koordinat verisine çevir###################
iller.crs    #iller koordinat dataframenin kord ref sist verir    epsig.io:4326 ara
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
iller_mercaor=iller.to_crs(epsg=3395)

# %%
iller_mercator.plot()
# Out:
# <AxesSubplot:>

# %%
#katmanları üst üste görselleştir
ax=iller.plot()

# %%
ax=iller.plot(edgecolor='k') #siyah çizgili

# %%
ax=iller.plot(edgecolor='k',facecolor='none') #çizgi siyah içi boş

# %%
ax=iller.plot(edgecolor='k',facecolor='none',figzise=(3,5))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-7a05d2ed3b8d> in <module>
# ----> 1 ax=iller.plot(edgecolor='k',figzise=(3,5))
#
# ~\anaconda3\envs\genv\lib\site-packages\geopandas\geodataframe.py in plot(self, *args, **kwargs)
#     919         from there.
#     920         """
# --> 921         return plot_dataframe(self, *args, **kwargs)
#     922
#     923     plot.__doc__ = plot_dataframe.__doc__
#
# ~\anaconda3\envs\genv\lib\site-packages\geopandas\plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     613
#     614     if column is None:
# --> 615         return plot_series(
#     616             df.geometry,
#     617             cmap=cmap,
#
# ...

# %%
ax=iller.plot(edgecolor='b',facecolor='none',figzise=(10,10))
nehirler.plot()
ax(xlim=(25,45),ylim=(35,43))
havalimanları.plot()(ax=ax)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-7d70441f9901> in <module>
# ----> 1 ax=iller.plot(edgecolor='b',facecolor='none',figzise=(10,10))
#       2 nehirler.plot()
#       3 ax(xlim=(25,45),ylim=(35,43))
#       4 havalimanları.plot()(ax=ax)
#
# ~\anaconda3\envs\genv\lib\site-packages\geopandas\geodataframe.py in plot(self, *args, **kwargs)
#     919         from there.
#     920         """
# --> 921         return plot_dataframe(self, *args, **kwargs)
#     922
#     923     plot.__doc__ = plot_dataframe.__doc__
#
# ~\anaconda3\envs\genv\lib\site-packages\geopandas\plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     613
#     614     if column is None:
# ...

# %% [markdown]
# # Veri Görselleştirme

# %%
iller_mercator=iller.to_crs(epsg=3395)   #epsgden bak metre hesabı

# %%
iller_mercator.plot() #I love my adction
# Out:
# <AxesSubplot:>

# %%
iller.plot() #derece olmalı kord sist dönüşümü
# Out:
# <AxesSubplot:>
